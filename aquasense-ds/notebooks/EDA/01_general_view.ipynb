# %% [markdown]
# # EDA - Qualidade da Água | Projeto AquaSense
#
# ## Contexto
# Este notebook apresenta a Análise Exploratória de Dados (EDA) de um dataset de qualidade da água, utilizado no contexto do projeto AquaSense.
#
# O conjunto de dados reúne medições de parâmetros físico-químicos da água em diferentes países (Canadá, China, Irlanda, e Estados Unidos), incluindo também o índice CCME WQI.
#
# ## Objetivo desta etapa
# O objetivo desta análise é compreender o comportamente dos dados antes de qualquer modelagem, buscando identificar padões, incosistências e limitações do dataset.
#
# De forma mais específica, pretende-se:
# - Entender a estrutura e composição dos dados
# - Identificart problemas de qualidade (valores nulos, inconsistências, etc.)
# - Analisar distribuições e possíveis outliers
# - Explorar relações entre variáveis
# - Identificar parâmetros compatíveis com a Resolução CONAMA 357/2005
#
# Essa estapa é fundamental para orientar decisões futuras, especialmente na construção de um rótulo classificatório adaptado ao contexto brasileiro.
#
# ## Ferramentas de visualização
# Para análise gráfica, será utilizada a biblioteca Plotly, devido à sua capacidade de gerar visualizações interativas, facilitando a interpretação dos dados.
#
# A análise será conduzida de forma progressiva, partindo de uma visão geral dos dados até uma abordagem orientada ao objetivo do projeto.

# %% [markdown]
# # Preparação do Ambiente
# Nesta seção, são importadas as bibliotecas necessárias para manipulação, análise e visualização dos dados. As ferramentas escolhidas permitem trabalhar com estruturas tabulares, realizar operações numéricas e construir gráficos que auxiliam na interpretação dos padrões do dataset.

# %%
# Manipulação de dados
import pandas as pd
import numpy as np

# Visualização de dados
import plotly.express as px
import plotly.graph_objects as go

# %%
import pandas as pd

# Carregar o dataset local
df = pd.read_csv("../../dataset/Combined_dataset.csv")

df.head()
# Out:
#   Country             Area Waterbody Type        Date  Ammonia (mg/l)  \
# 0  Canada  SE649035-145565          River  12-01-1974        0.059248
# 1  Canada  SE649035-145565          River  12-01-1975        0.039821
# 2  Canada  SE649035-145565          River  12-01-1976        0.031341
# 3  Canada  SE649035-145565          River  12-01-1977        0.020501
# 4  Canada  SE649035-145565          River  12-01-1978        0.020023
#
#    Biochemical Oxygen Demand (mg/l)  Dissolved Oxygen (mg/l)  \
# 0                              1.30                   8.1500
# 1                              1.38                   7.8000
# 2                              2.23                   7.8000
# 3                              1.61                   8.1500
# 4                              1.64                   4.3708
#
#    Orthophosphate (mg/l)  pH (ph units)  Temperature (cel)  Nitrogen (mg/l)  \
# 0               0.011917        8.07500              9.885         0.343917
# ...

# %% [markdown]
# # Conhecimento Estrutural do Dataset

# %% [markdown]
# ## Dimensão do Dataset
# Antes de analisar qualquer conteúdo, precisamos entender o tamanho da base. Isos porque a escala dos dados influencia diretamente toda a análise.
#
#
# ---
#
#
#
# **Pergunta que queremos responder**
#
#
# *   Quantas observações existem?
# *   Quantas variáveis estão disponíveis?
#
#
# ---
#
#
# **Objetivo**
#
#
# *   Identificar o volume dos dados
# *   Ter uma noção da dimensão do problema

# %%
df.shape
# Out:
# (2827977, 14)

# %% [markdown]
# *   2.827.977 - número de linhas (registros)
# *   14 - números de colunas (variáveis)
#
# Essa etapa é importante porque nos ajuda a responder a seguinte pergunta: qual é o tamanho da base com a qual estamos trabalhando? Saber isso desde o início permite que a análise seja conduzida com mais consciência, já que o comportamento dos dados e o tipo de cuidado analítico necessário podem mudar bastante dependendo da escala da base.

# %% [markdown]
# ## Identificação das variáveis
# Agora que sabemos o tamanho da base, precisamos entender o que ela contém.
#
#
# ---
#
#
# **Pergunta que queremos responder**
#
#
# *   Quais informações estão disponíveis no dataset?
#
#
# ---
# **Objetivo**
#
#
# *   Mapear todas as variáveis
# *   Identificar possíveis variáveis importantes

# %%
colunas_df = pd.DataFrame({
    'Variáveis': df.columns

})

display(colunas_df)
# Out:
#                            Variáveis
# 0                            Country
# 1                               Area
# 2                     Waterbody Type
# 3                               Date
# 4                     Ammonia (mg/l)
# 5   Biochemical Oxygen Demand (mg/l)
# 6            Dissolved Oxygen (mg/l)
# 7              Orthophosphate (mg/l)
# 8                      pH (ph units)
# 9                  Temperature (cel)
# 10                   Nitrogen (mg/l)
# 11                    Nitrate (mg/l)
# 12                       CCME_Values
# 13                          CCME_WQI

# %% [markdown]
# A partir da organização das colunas em formato de tabela, é possível identificar diferentes tipos de variáveis presentes no dataset, cada uma com um papel específico dentro da análise.
#
# De forma geral, as variáveis podem ser classificadas em três grupos principais:
#
# * **Variáveis de contexto:** incluem informações como Country, Area, Waterbody Type e Date. Essas variáveis ajudam a entender onde e quando os dados foram coletados, sendo importantes para análises comparativas e segmentações, mas não representam diretamente a qualidade da água.
#
# * **Variáveis físico-químicas (potenciais variáveis de entrada):** incluem parâmetros como Ammonia, Biochemical Oxygen Demand, Dissolved Oxygen, Orthophosphate, pH, Temperature, Nitrogen e Nitrate. Essas variáveis são diretamente relacionadas às características da água e possuem grande relevância para a análise, pois são os principais fatores que influenciam sua qualidade.
#
# * **Variáveis de resultado (potenciais variáveis-alvo):** destacam-se CCME_Values e CCME_WQI. A variável CCME_Values representa um índice numérico de qualidade da água, enquanto CCME_WQI apresenta uma classificação categórica (como "Excellent"). Essas variáveis são fortes candidatas a variável-alvo em modelos de machine learning, pois sintetizam a qualidade da água a partir dos parâmetros analisados.
#
#
# Além disso, observa-se que os nomes das colunas estão, em geral, bem definidos e coerentes com os parâmetros analisados. No entanto, alguns nomes mais longos, como Biochemical Oxygen Demand, podem exigir padronização futura para facilitar a manipulação dos dados.

# %% [markdown]
# ## Visualização inicial
# Agora vamos olhar os dados como eles realmente aparecem.
#
#
# ---
#
#
# **Pergunta que queremos responder**
#
#
# *   Como os dados estão organizados na prática?
#
#
# ---
#
#
# **Objetivo**
#
# *   Ver formato real dos dados
# *   Identificar inconsistências visuais

# %%
df.head()
df.tail()
# Out:
#          Country                                           Area  \
# 2827972  Ireland  Cork Harbour, Moy Killala, YELLOW (KNOCK)_020
# 2827973  Ireland  Cork Harbour, Moy Killala, YELLOW (KNOCK)_020
# 2827974  Ireland  Cork Harbour, Moy Killala, YELLOW (KNOCK)_020
# 2827975  Ireland  Cork Harbour, Moy Killala, YELLOW (KNOCK)_020
# 2827976  Ireland  Cork Harbour, Moy Killala, YELLOW (KNOCK)_020
#
#         Waterbody Type        Date  Ammonia (mg/l)  \
# 2827972          River  21-06-2022           0.024
# 2827973          River  28-09-2022           0.038
# 2827974          River  29-11-2022           0.035
# 2827975          River  07-02-2023           0.046
# 2827976          River  11-04-2023           0.020
#
#          Biochemical Oxygen Demand (mg/l)  Dissolved Oxygen (mg/l)  \
# 2827972                               1.4                   4.2930
# 2827973                               1.4                   4.4955
# ...

# %% [markdown]
# A visualização das primeiras e últimas linhas permite observar como os dados aparecem na prática.
#
# Os registros seguem um padrão consistente, em que cada linha representa uma medição de qualidade da água associada a um local e uma data específica. Os valores numéricos aparentam estar dentro de faixas esperadas, indicando coerência inicial dos dados.
#
# Também é possível notar a presença de muitas casas decimais em algumas variáveis e a necessidade de tratar a coluna de data para análises futuras.
#
# De forma geral, não foram identificadas inconsistências visuais relevantes neste primeiro contato, permitindo avançar para as próximas etapas da análise.

# %% [markdown]
# ## Estrutura técnica do dataset
# Nesta etapa, utilizamos o método df.info() para visualizar a estrutura geral do dataset, incluindo quantidade de registros, número de colunas, tipos de dados e uso de memória.
#
#
#
# ---
#
# **Pergunta que queremos responder**
#
#
# *   Como os dados estão estruturados tecnicamente e quais pontos de atenção precisam ser observados antes de aprofundar a análise?
#
#
#
# ---
#
# **Objetivo**
#
#
#
#
#
# *   Compreender a organização interna do dataset
# *   Verificar qualidade de entradas e tipos de variáveis
#
#
# *   Verificar possíveis inconsistências de tipagem e aspectos que possam impactar as próximas etapas da EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2827977 entries, 0 to 2827976
# Data columns (total 14 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   Country                           object
#  1   Area                              object
#  2   Waterbody Type                    object
#  3   Date                              object
#  4   Ammonia (mg/l)                    float64
#  5   Biochemical Oxygen Demand (mg/l)  float64
#  6   Dissolved Oxygen (mg/l)           float64
#  7   Orthophosphate (mg/l)             float64
#  8   pH (ph units)                     float64
#  9   Temperature (cel)                 float64
#  10  Nitrogen (mg/l)                   float64
#  11  Nitrate (mg/l)                    float64
#  12  CCME_Values                       float64
#  13  CCME_WQI                          object
# dtypes: float64(9), object(5)
# memory usage: 302.1+ MB

# %% [markdown]
# O dataset possui 2.827.977 entradas, o que indica uma base de dados muito rica e pesada (ocupa cerca de 302 MB de memória RAM).
#
# As colunas de medições químicas (Amônia, Oxigênio, pH, Temperatura, etc.) estão corretamente tipadas como float64 (números decimais).
#
# A coluna Date está como object (texto).
# Ponto de atenção: Para fazer análises ao longo do tempo, precisaremos convertê-la para o formato de data real futuramente.

# %% [markdown]
# ## Primeiras impressões sobre o dataset
# Nesta etapa, reunimos as observações iniciais a partir da visualização da base, considerando sua dimensão, estrutura e aparência geral dos dados.
#
#
#
# ---
#
# O dataset apresenta um volume elevado de dados, com 2.827.977 registros e 14 variáveis, indicando uma base robusta para exploração. A organização das colunas sugere uma divisão clara entre variáveis de contexto, parâmetros físico-químicos e indicadores de qualidade da água, o que favorece diferentes tipos de análise.
#
# A visualização das primeiras e últimas linhas indica um padrão consistente nos registros, sem inconsistências visuais relevantes neste primeiro contato.
#
# Por outro lado, já é possível identificar pontos de atenção, como a coluna Date em formato object, que exigirá conversão para análises temporais, além do tamanho da base, que pode impactar o processamento. De forma geral, os dados se mostram bem estruturados, permitindo avançar para as próximas etapas da EDA.

# %% [markdown]
# # Qualidade dos Dados

# %% [markdown]
# ## Checagem de valores nulos
# Nesta etapa, analisamos a presença de valores ausentes no dataset. A identificação de dados faltantes é fundamental, pois a ausência de informações pode comprometer análises estatísticas, visualizações e o desempenho de modelos de machine learning.
#
#
#
# ---
#
# **Pergunta que queremos responder**
#
#
# *   Existem valores nulos no dataset que possam impactar a análise?
#
#
# ---
#
# **Objetivo**
#
#
# *   Verificar a existência de valores ausentes nas colunas
#
#
# *   Identificar possíveis variáveis com maior incidência de nulos
# *   Avaliar a necessidade de tratamento dos dados antes das próximas etapas

# %%
df.isnull().sum()
# Out:
# Country                             0
# Area                                0
# Waterbody Type                      0
# Date                                0
# Ammonia (mg/l)                      0
# Biochemical Oxygen Demand (mg/l)    0
# Dissolved Oxygen (mg/l)             0
# Orthophosphate (mg/l)               0
# pH (ph units)                       0
# Temperature (cel)                   0
# Nitrogen (mg/l)                     0
# Nitrate (mg/l)                      0
# CCME_Values                         0
# CCME_WQI                            0
# dtype: int64

# %%
percentual_nulos = (df.isnull().sum() / len(df)) * 100

pd.DataFrame({
    "Percentual de Nulos (%)": percentual_nulos
}).sort_values(by="Percentual de Nulos (%)", ascending=False)
# Out:
#                                   Percentual de Nulos (%)
# Country                                               0.0
# Area                                                  0.0
# Waterbody Type                                        0.0
# Date                                                  0.0
# Ammonia (mg/l)                                        0.0
# Biochemical Oxygen Demand (mg/l)                      0.0
# Dissolved Oxygen (mg/l)                               0.0
# Orthophosphate (mg/l)                                 0.0
# pH (ph units)                                         0.0
# Temperature (cel)                                     0.0
# Nitrogen (mg/l)                                       0.0
# Nitrate (mg/l)                                        0.0
# CCME_Values                                           0.0
# CCME_WQI                                              0.0

# %% [markdown]
# A análise indica que o dataset não possui valores nulos em nenhuma das colunas, demonstrando um alto nível de completude dos dados. Isso é um ponto positivo, pois elimina, neste momento, a necessidade de aplicação de técnicas de tratamento como imputação ou remoção de registros.
#
# Essa característica sugere que o processo de coleta ou consolidação dos dados foi bem estruturado, permitindo que a análise prossiga diretamente para etapas mais avançadas, sem necessidade de intervenções relacionadas à ausência de informações.

# %% [markdown]
# ## Análise de duplicatas
#
# Nesta etapa, verificamos a existência de registros duplicados no dataset. A identificação de duplicatas é importante porque repetições indevidas podem distorcer análises estatísticas, frequências e resultados de modelos, comprometendo a confiabilidade da base.
#
#
#
# ---
#
# **Pergunta que queremos responder**
#
#
# *   Existem registros duplicados no dataset que possam comprometer a análise?
#
#
# ---
#
# **Objetivo**
#
#
# *   Identificar a presença de registros repetidos
# *   Avaliar se há risco de distorção nos resultados
#
#
# *   Verificar a necessidade de remoção ou tratamento dessas duplicatas

# %%
# Quantidade de duplicatas
duplicatas = df.duplicated().sum()
print(f"Quantidade de registros duplicados: {duplicatas}")

# Visualização das duplicatas (se existirem)
df[df.duplicated()]
# Out:
# Quantidade de registros duplicados: 9971
#          Country                                      Area Waterbody Type  \
# 3516      Canada                           SE616397-135001          River
# 3522      Canada                              ESGV09089001          River
# 3524      Canada                                   HR21001          River
# 3525      Canada                                   FI34398           Lake
# 3562      Canada                                   FISW_32           Lake
# ...          ...                                       ...            ...
# 2802991  Ireland  Blackwater_Munster, Blackwater (Munster)          River
# 2803180  Ireland  Blackwater_Munster, Blackwater (Munster)          River
# 2803748  Ireland  Blackwater_Munster, Blackwater (Munster)          River
# 2803768  Ireland  Blackwater_Munster, Blackwater (Munster)          River
# 2803911  Ireland  Blackwater_Munster, Blackwater (Munster)          River
#
# ...

# %% [markdown]
# ## Correções básicas
# Nesta etapa, são identificadas possíveis correções iniciais necessárias para melhorar a consistência e a adequação do dataset. Essas correções não representam um pré-processamento completo, mas sim ajustes básicos que facilitam as próximas etapas da análise.

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2827977 entries, 0 to 2827976
# Data columns (total 14 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   Country                           object
#  1   Area                              object
#  2   Waterbody Type                    object
#  3   Date                              datetime64[ns]
#  4   Ammonia (mg/l)                    float64
#  5   Biochemical Oxygen Demand (mg/l)  float64
#  6   Dissolved Oxygen (mg/l)           float64
#  7   Orthophosphate (mg/l)             float64
#  8   pH (ph units)                     float64
#  9   Temperature (cel)                 float64
#  10  Nitrogen (mg/l)                   float64
#  11  Nitrate (mg/l)                    float64
#  12  CCME_Values                       float64
#  13  CCME_WQI                          object
# dtypes: datetime64[ns](1), float64(9), object(4)
# memory usage: 302.1+ MB

# %% [markdown]
# A partir das análises anteriores, foi possível identificar alguns ajustes iniciais necessários para melhorar a consistência do dataset.
#
# Um dos principais pontos foi a coluna Date, que inicialmente estava em formato textual (object). Para permitir análises temporais mais adequadas, essa variável foi convertida para o tipo datetime, tornando possível a realização de estudos ao longo do tempo, como tendências e padrões sazonais.
#
# Além disso, foram identificados 9.971 registros duplicados no dataset. Neste momento, optou-se por não realizar a remoção dessas duplicatas, mantendo a base original para preservar a integridade dos dados durante a análise exploratória.
#
# De forma geral, essas correções iniciais contribuem para tornar a base mais adequada para as próximas etapas, sem alterar significativamente sua estrutura original.

# %% [markdown]
# # Estatísticas Descritivas

# %% [markdown]
# ## Estatísticas descritivas iniciais com describe()
# Nesta etapa, utilizamos o método describe() para obter um resumo estatístico das variáveis numéricas do dataset. Essa função apresenta medidas importantes como média, mediana, desvio padrão, valores mínimos e máximos e quartis, permitindo uma visão inicial mais completa sobre o comportamento dos dados.
#
#
# ---
# **Pergunta que queremos responder**
#
#
# *   Como as variáveis numéricas do dataset se comportam em termos de tendência central, dispersão e distribuição inicial?
#
#
# ---
#
# **Objetivo**
#
#
# *   Observar medidas de tendência central, como média e mediana
# *   Avaliar a dispersão dos dados por meio do desvio padrão
#
#
# *   Identificar a amplitude dos valores com base no mínimo e no máximo
# *   Analisar os quartis para compreender melhor a distribuição das variáveis
#
#
# *   Detectar indícios iniciais de assimetrias e possíveis valores extremos

# %%
df.describe()
# Out:
#                                 Date  Ammonia (mg/l)  \
# count                        2827977    2.827977e+06
# mean   2007-05-15 06:45:57.940675328    1.171360e+00
# min              1940-01-02 00:00:00   -5.000000e-03
# 25%              2003-07-03 00:00:00    3.000000e-02
# 50%              2008-10-23 00:00:00    5.500000e-02
# 75%              2014-12-09 00:00:00    3.170000e-01
# max              2023-12-17 00:00:00    2.000000e+02
# std                              NaN    5.668927e+00
#
#        Biochemical Oxygen Demand (mg/l)  Dissolved Oxygen (mg/l)  \
# count                      2.827977e+06             2.827977e+06
# mean                       4.886554e+00             1.000798e+01
# min                       -2.000000e+00             0.000000e+00
# 25%                        1.600000e+00             9.860000e+00
# 50%                        2.700000e+00             1.020000e+01
# 75%                        2.830000e+00             1.100000e+01
# ...

# %% [markdown]
# **Completude dos dados**
#
# A estatística count indica que todas as variáveis possuem 2.827.977 registros, confirmando a ausência de valores nulos e a consistência da base para análise.
#
#
# ---
#
#
# **Tendência central**
#
# Ao observar as medidas de tendência central, especialmente média e mediana, percebe-se que algumas variáveis apresentam diferenças relevantes entre esses valores. Isso ocorre, por exemplo, em Ammonia, Orthophosphate, Biochemical Oxygen Demand, Nitrogen e Nitrate, cujas médias são superiores às medianas. Esse comportamento sugere distribuições assimétricas, nas quais a maior parte dos valores está concentrada em faixas mais baixas, enquanto alguns valores elevados puxam a média para cima. Esse resultado reforça a importância de não analisar apenas a média de forma isolada.
#
#
# ---
#
#
# **Dispersão dos dados**
#
# A análise do desvio padrão (std) mostra que algumas variáveis apresentam variabilidade considerável, como Biochemical Oxygen Demand, Nitrogen, Nitrate e Ammonia. Isso indica que os dados não estão uniformemente concentrados em torno da média, mas distribuídos de maneira mais espalhada. Já variáveis como pH e Dissolved Oxygen apresentam desvio padrão relativamente menor, sugerindo comportamento mais estável em comparação com as demais.
#
#
# ---
#
#
# **Amplitude e valores extremos**
#
# A comparação entre os valores mínimos e máximos revela amplitudes bastante elevadas em algumas variáveis, o que chama atenção para a presença de valores extremos. Além disso, a existência de valores mínimos negativos em variáveis como Ammonia, Biochemical Oxygen Demand, Orthophosphate, pH e Temperature merece atenção, pois alguns desses valores podem não fazer sentido físico ou podem estar associados a convenções laboratoriais, limites de detecção ou inconsistências de registro. Esses casos precisarão ser analisados com mais cuidado nas etapas seguintes.
#
#
# ---
#
#
# **Quartis e indícios de outliers**
#
# Os quartis ajudam a entender onde a maior parte dos dados está concentrada. Em várias variáveis, observa-se que o terceiro quartil (Q3) está muito distante do valor máximo, indicando a presença de valores muito acima do comportamento mais comum da base. Isso aparece com bastante força em variáveis como Ammonia, Biochemical Oxygen Demand, Orthophosphate e Nitrate. Esses resultados sugerem indícios iniciais de outliers, que ainda precisarão ser confirmados por análises visuais e métodos específicos, como boxplots e avaliação por intervalo interquartil.
#
# ---
#
#
# **Cobertura temporal**
#
# A variável Date indica registros entre 1940 e 2023, mostrando uma ampla cobertura temporal que pode ser explorada em análises futuras.
#
#
# ---
#
# De forma geral, as estatísticas descritivas mostram que o dataset é amplo, completo e analiticamente rico, mas também revelam sinais importantes de assimetria, alta variabilidade em algumas variáveis e possíveis valores extremos. Esses achados são fundamentais porque orientam as próximas etapas da EDA: a análise da distribuição das variáveis, a visualização de outliers por histogramas e boxplots, e a avaliação mais crítica da consistência dos parâmetros em relação ao contexto do projeto.
